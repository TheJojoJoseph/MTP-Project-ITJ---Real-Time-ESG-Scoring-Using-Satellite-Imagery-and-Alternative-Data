# %% [markdown]
# # Real-Time ESG Scoring Using Satellite Imagery & Alternative Data
#
# End-to-end prototype of a real-time ESG scoring pipeline using:
# - Synthetic satellite imagery + alternative data
# - Vision Transformer (ViT) feature extractor
# - Graph Neural Network (GraphSAGE / GAT) over a company graph
# - Streaming simulation with stateful ESG score updates.

# %% [markdown]
# ## 1. Environment & Imports
# Requires Python 3.10+ and packages from `requirements.txt`.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (2.9.1)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (0.24.1)
# Requirement already satisfied: torch-geometric in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (2.7.0)
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (4.57.3)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (11.0.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (3.6)
# Requirement already satisfied: kafka-python in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (2.3.0)
# Requirement already satisfied: jupyter in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 3)) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 3)) (4.13.2)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 3)) (79.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 3)) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 3)) (2025.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: aiohttp in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch-geometric->-r requirements.txt (line 9)) (3.13.2)
# Requirement already satisfied: psutil>=5.8.0 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from torch-geometric->-r requirements.txt (line 9)) (7.0.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch-geometric->-r requirements.txt (line 9)) (2.32.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch-geometric->-r requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: xxhash in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch-geometric->-r requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 10)) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 10)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 10)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: notebook in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 14)) (7.5.0)
# Requirement already satisfied: jupyter-console in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 14)) (6.6.3)
# Requirement already satisfied: nbconvert in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 14)) (7.16.6)
# Requirement already satisfied: ipykernel in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from jupyter->-r requirements.txt (line 14)) (6.29.5)
# Requirement already satisfied: ipywidgets in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 14)) (8.1.8)
# Requirement already satisfied: jupyterlab in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 14)) (4.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp->torch-geometric->-r requirements.txt (line 9)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp->torch-geometric->-r requirements.txt (line 9)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp->torch-geometric->-r requirements.txt (line 9)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp->torch-geometric->-r requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp->torch-geometric->-r requirements.txt (line 9)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp->torch-geometric->-r requirements.txt (line 9)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp->torch-geometric->-r requirements.txt (line 9)) (1.22.0)
# Requirement already satisfied: appnope in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (9.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 14)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 14)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 14)) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->torch->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 14)) (3.0.51)
# Requirement already satisfied: pygments in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 14)) (2.19.1)
# Requirement already satisfied: async-lru>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 14)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 14)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 14)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 14)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 14)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 14)) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 14)) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 14)) (6.3.0)
# Requirement already satisfied: defusedxml in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 14)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 14)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 14)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 14)) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 14)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 14)) (1.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->torch-geometric->-r requirements.txt (line 9)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->torch-geometric->-r requirements.txt (line 9)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->torch-geometric->-r requirements.txt (line 9)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->torch-geometric->-r requirements.txt (line 9)) (2025.1.31)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 14)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: decorator in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 14)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 14)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 14)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 14)) (4.9.0)
# Requirement already satisfied: stack_data in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 14)) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 14)) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 14)) (2.21.2)
# Requirement already satisfied: wcwidth in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 14)) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 14)) (2.8)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (25.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 14)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 14)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 14)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/jojojoseph/Library/Python/3.12/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 14)) (0.2.3)
# Requirement already satisfied: fqdn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (1.5.1)
# Requirement already satisfied: isoduration in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (3.0.0)
# Requirement already satisfied: uri-template in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (2.23)
# Requirement already satisfied: arrow>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 14)) (1.4.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
print(sys.version)

import numpy as np
import pandas as pd
import torch

from esg_pipeline.data_ingestion import build_merged_entity_frame
from esg_pipeline.vit_module import ViTFeatureExtractor, encode_company_images, get_dummy_attention_map
from esg_pipeline.gnn_module import build_company_graph, GraphSAGEESG, GATESG
from esg_pipeline.streaming import InMemoryTopic, ESGConsumer, start_background_producer
from esg_pipeline.scoring import compute_esg_subscores, update_scores_with_stream_event
from esg_pipeline.visualization import plot_satellite_images, plot_attention_heatmap, plot_company_graph, plot_esg_dashboard

import matplotlib.pyplot as plt
# %matplotlib inline

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 3.13.3 (main, Apr  8 2025, 13:54:08) [Clang 16.0.0 (clang-1600.0.26.6)]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 6
#       4 import numpy as np
#       5 import pandas as pd
# ----> 6 import torch
#       8 from esg_pipeline.data_ingestion import build_merged_entity_frame
#       9 from esg_pipeline.vit_module import ViTFeatureExtractor, encode_company_images, get_dummy_attention_map
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# pip install -r requirements.txt

# %% [markdown]
# ## 2. Real Data Ingestion from Multiple ESG Sources
#
# In a production-grade ESG scoring system, we replace synthetic data with *real* signals coming from multiple heterogeneous sources:
#
# - **Corporate fundamentals & disclosures**
#   Structured data such as financial statements, sustainability reports, emissions data, and regulatory filings (e.g., CDP, company 10-K/annual reports) are ingested as tabular features.
#
# - **News & long-form text**
#   News APIs and document feeds (e.g., major financial news providers) are streamed, then processed with NLP models to detect ESG-relevant events such as controversies, regulatory actions, or environmental incidents.
#
# - **Social media & alternative text data**
#   Posts from platforms like X/Reddit, NGO reports, and blogs are ingested as unstructured text. Sentiment models and ESG-specific classifiers turn these into time-stamped sentiment and controversy features at the company level.
#
# - **Satellite imagery & remote sensing**
#   Public and commercial satellite sources (e.g., Sentinel, Landsat, Planet) are used to capture objective environmental indicators such as deforestation, flaring, water stress, and physical climate risks near company facilities. Vision models (like ViT or CNNs) convert imagery into spatial-temporal risk features.
#
# - **Geospatial & contextual data**
#   Data such as asset locations, weather and climate projections, land use, and population density are joined via geocoding and spatial joins to provide context for environmental impacts.
#
# AI and big-data infrastructure are then used to:
#
# - **Normalize & link entities** across all sources to a unified company identifier.
# - **Apply ML/NLP models** (sentiment, topic classification, event detection) to convert raw text into structured ESG event streams.
# - **Extract image embeddings** from satellite tiles using pre-trained or fine-tuned vision models.
# - **Aggregate features over time** into E, S, and G factor vectors per company.
#
# The rest of this notebook keeps a synthetic setup for reproducibility, but the same pipeline structure (ingestion → embeddings → graph → ESG scoring → streaming updates) is directly adaptable to these real-world data feeds.

# %%
n_companies = 6
companies, image_map = build_merged_entity_frame(n_companies=n_companies)
companies.head()

# %%
plot_satellite_images(image_map, max_images=4)

# %% [markdown]
# ## 3. ViT Satellite Feature Extraction
# Encode each company image using a pre-trained ViT.

# %%
vit_extractor = ViTFeatureExtractor(model_name='google/vit-base-patch16-224', device=device)
company_vit_embs = encode_company_images(image_map, vit_extractor)
len(company_vit_embs), next(iter(company_vit_embs.values())).shape

# %%
first_cid = list(image_map.keys())[0]
attn_map = get_dummy_attention_map(image_map[first_cid])
plot_attention_heatmap(image_map[first_cid], attn_map)

# %% [markdown]
# ## 4. Graph Construction & GNN Embeddings
# Build a company graph and run a GNN (GraphSAGE or GAT).

# %%
graph_data, id_to_idx = build_company_graph(companies, company_vit_embs)
graph_data

# %%
in_dim = graph_data.x.shape[1]
hidden_dim = 128
out_dim = 64
use_gat = False

if use_gat:
    gnn_model = GATESG(in_dim, hidden_dim, out_dim).to(device)
else:
    gnn_model = GraphSAGEESG(in_dim, hidden_dim, out_dim).to(device)

gnn_model.eval()
with torch.inference_mode():
    graph_data = graph_data.to(device)
    node_embs = gnn_model(graph_data).cpu()
node_embs.shape

# %%
idx_to_id = {idx: cid for cid, idx in id_to_idx.items()}
gnn_embeddings = {idx_to_id[i]: node_embs[i] for i in range(node_embs.shape[0])}
list(gnn_embeddings.items())[:2]

# %%
plot_company_graph(companies, id_to_idx)

# %% [markdown]
# ## 5. ESG Scoring (Static)
# Combine GNN embeddings + features into E/S/G subscores and overall ESG.

# %%
scores = compute_esg_subscores(companies, gnn_embeddings)
scores

# %%
plot_esg_dashboard(scores)

# %% [markdown]
# ## 6. Streaming Simulation & Real-Time Updates
# Simulate ESG events and update the score table incrementally.

# %%
topic = InMemoryTopic()
consumer = ESGConsumer(topic)
company_ids = companies['company_id'].tolist()

producer_thread = start_background_producer(topic, company_ids, event_rate_hz=3.0, stop_after=5.0)
producer_thread.join()

updated_scores = scores.copy()
event_log = []
for ev in consumer.iterate(max_events=50, timeout=0.5):
    d = {'company_id': ev.company_id, 'event_type': ev.event_type, 'payload': ev.payload}
    event_log.append(d)
    updated_scores = update_scores_with_stream_event(updated_scores, d)
len(event_log), updated_scores.head()

# %%
comparison = scores[['company_id', 'ESG_score']].merge(
    updated_scores[['company_id', 'ESG_score']], on='company_id', suffixes=('_orig', '_updated')
)
comparison

# %%
plot_esg_dashboard(updated_scores)

# %% [markdown]
# ## 7. Final ESG Scores
# Sorted ESG scores (post-streaming) for sample companies.

# %%
final_scores = updated_scores.sort_values('ESG_score', ascending=False).reset_index(drop=True)
final_scores
